# %% [markdown]
# **1. Add the current date to the text file today.txt as a string.**

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 08-09-2022

# %% [markdown]
# **2. Read the text file today.txt into the string today_string**

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 08-09-2022

# %% [markdown]
# **3. Parse the date from today_string.**

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-09-08 00:00:00

# %% [markdown]
# **4. List the files in your current directory**

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# application_log.txt
# books.csv
# books.db
# new.jpg
# Python_Assignment1_16.ipynb
# Python_Assignment_10.ipynb
# Python_Assignment_11.ipynb
# Python_Assignment_12.ipynb
# Python_Assignment_13.ipynb
# Python_Assignment_14.ipynb
# Python_Assignment_15.ipynb
# Python_Assignment_17.ipynb
# Python_Assignment_18.ipynb
# Python_Assignment_19.ipynb
# Python_Assignment_20.ipynb
# Python_Assignment_21.ipynb
# Python_Assignment_9.ipynb
# Redis-x64-3.0.504.7z
# SQL.txt
# test.txt
# today.txt
# university_records.csv
# zoo.py
# $I0ERT6O.ipynb
# $I153TA0.ipynb
# $I351OW0.ipynb
# $I3H5A1F.ipynb
# $IBG9K23.ipynb
# $ID5EH4U.ipynb
# $IEECQQA.txt
# $IIJEA0Z.log
# $ILQG1E3.ipynb
# $IMGXQDI.ipynb
# $INDFVG5.ipynb
# $IOBJ7XW.ipynb
# $IQRK5M9
# $IT048AP.ipynb
# $IY42G4Z.ipynb
# $IYFA4DO.txt
# $IZEP3OQ.py
# $R0ERT6O.ipynb
# $R153TA0.ipynb
# $R351OW0.ipynb
# $R3H5A1F.ipynb
# $RBG9K23.ipynb
# $RD5EH4U.ipynb
# $REECQQA.txt
# $RIJEA0Z.log
# $RLQG1E3.ipynb
# $RMGXQDI.ipynb
# $RNDFVG5.ipynb
# $ROBJ7XW.ipynb
# $RT048AP.ipynb
# $RY42G4Z.ipynb
# $RYFA4DO.txt
# $RZEP3OQ.py
# desktop.ini
# test1.cpython-39.pyc
# Advance_Python_Assignment11_shreya_ineuron-checkpoint.ipynb
# Advance_Python_Assignment12_shreya_ineuron-checkpoint.ipynb
# Advance_Python_Assignment13_shreya_ineuron-checkpoint.ipynb
# Advance_Python_Assignment14_shreya_ineuron-checkpoint.ipynb
# Advance_Python_Assignment15_shreya_ineuron-checkpoint.ipynb
# Advance_Python_Assignment16-checkpoint.ipynb
# Advance_Python_Assignment17-checkpoint.ipynb
# Advance_Python_Assignment18-checkpoint.ipynb
# Advance_Python_Assignment19-checkpoint.ipynb
# Advance_Python_Assignment20-checkpoint.ipynb
# Advance_Python_Assignment21-checkpoint.ipynb
# Advance_Python_Assignment22-checkpoint.ipynb
# Advance_Python_Assignment23-checkpoint.ipynb
# Advance_Python_Assignment24-checkpoint.ipynb
# Advance_Python_Assignment25-checkpoint.ipynb
# Assignment_3_shreya_ineuron-checkpoint.ipynb
# Assignment_4_shreya_ineuron-checkpoint.ipynb
# Assignment_5_shreya_ineuron-checkpoint.ipynb
# Assignment_6_shreya_ineuron-checkpoint.ipynb
# Assignment_7_shreya_ineuron-checkpoint.ipynb
# Assignment_8_shreya_ineuron-checkpoint.ipynb
# casandra-checkpoint.ipynb
# Exception Handling-checkpoint.ipynb
# FUNCTIONS-checkpoint.ipynb
# Iterator & Generator-checkpoint.ipynb
# Logging-checkpoint.ipynb
# Machine_Learning_Assignment1_shreya_ineuron-checkpoint.ipynb
# modules and packages-checkpoint.ipynb
# OOPS-checkpoint.ipynb
# Programmimg_Assignment5_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment01-checkpoint.ipynb
# Programming_Assignment02_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment03_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment04_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment05_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment06_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment07_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment08_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment09_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment10_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment11_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment12_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment13_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment14_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment15_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment16_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment17_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment18_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment1_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment20_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment21_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment22_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment23_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment24_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment25_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment2_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment3_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment4_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment6_shreys_ineuron-checkpoint.ipynb
# Programming_Assignment9_shreya_ineuron-checkpoint.ipynb
# Programmming_Assignment19_shreya_ineuron-checkpoint.ipynb
# Python_Assessment_ineuron-checkpoint.ipynb
# Python_Assignment1_16-checkpoint.ipynb
# Python_Assignment_10-checkpoint.ipynb
# Python_Assignment_11-checkpoint.ipynb
# Python_Assignment_12-checkpoint.ipynb
# Python_Assignment_13-checkpoint.ipynb
# Python_Assignment_14-checkpoint.ipynb
# Python_Assignment_15-checkpoint.ipynb
# Python_Assignment_17-checkpoint.ipynb
# Python_Assignment_18-checkpoint.ipynb
# Python_Assignment_19-checkpoint.ipynb
# Python_Assignment_20-checkpoint.ipynb
# Python_Assignment_21-checkpoint.ipynb
# Python_Assignment_9-checkpoint.ipynb
# SQL LITE-checkpoint.ipynb
# SQL_Assignment6-checkpoint.ipynb
# SQL_Assignment7_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment8_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment9_shreya_ineuron-checkpoint.ipynb
# task-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# Advance_Python_Assignment11_shreya_ineuron.ipynb
# Advance_Python_Assignment12_shreya_ineuron.ipynb
# Advance_Python_Assignment13_shreya_ineuron.ipynb
# Advance_Python_Assignment14_shreya_ineuron.ipynb
# Advance_Python_Assignment15_shreya_ineuron.ipynb
# Advance_Python_Assignment16.ipynb
# Advance_Python_Assignment17.ipynb
# Advance_Python_Assignment18.ipynb
# Advance_Python_Assignment19.ipynb
# Advance_Python_Assignment20.ipynb
# Advance_Python_Assignment21.ipynb
# Advance_Python_Assignment22.ipynb
# Advance_Python_Assignment23.ipynb
# Advance_Python_Assignment24.ipynb
# Advance_Python_Assignment25.ipynb
# Assignment_3_shreya_ineuron.ipynb
# Assignment_4_shreya_ineuron.ipynb
# Assignment_5_shreya_ineuron.ipynb
# Assignment_6_shreya_ineuron.ipynb
# Assignment_7_shreya_ineuron.ipynb
# Assignment_8_shreya_ineuron.ipynb
# Programmimg_Assignment5_shreya_ineuron.ipynb
# Programming_Assignment01.ipynb
# Programming_Assignment02_shreya_ineuron.ipynb
# Programming_Assignment03_shreya_ineuron.ipynb
# Programming_Assignment04_shreya_ineuron.ipynb
# Programming_Assignment05_shreya_ineuron.ipynb
# Programming_Assignment06_shreya_ineuron.ipynb
# Programming_Assignment07_shreya_ineuron.ipynb
# Programming_Assignment08_shreya_ineuron.ipynb
# Programming_Assignment09_shreya_ineuron.ipynb
# Programming_Assignment10_shreya_ineuron.ipynb
# Programming_Assignment11_shreya_ineuron.ipynb
# Programming_Assignment12_shreya_ineuron.ipynb
# Programming_Assignment13_shreya_ineuron.ipynb
# Programming_Assignment14_shreya_ineuron.ipynb
# Programming_Assignment15_shreya_ineuron.ipynb
# Programming_Assignment16_shreya_ineuron.ipynb
# Programming_Assignment17_shreya_ineuron.ipynb
# Programming_Assignment18_shreya_ineuron.ipynb
# Programming_Assignment1_shreya_ineuron.ipynb
# Programming_Assignment20_shreya_ineuron.ipynb
# Programming_Assignment21_shreya_ineuron.ipynb
# Programming_Assignment22_shreya_ineuron.ipynb
# Programming_Assignment23_shreya_ineuron.ipynb
# Programming_Assignment24_shreya_ineuron.ipynb
# Programming_Assignment25_shreya_ineuron.ipynb
# Programming_Assignment2_shreya_ineuron.ipynb
# Programming_Assignment3_shreya_ineuron.ipynb
# Programming_Assignment4_shreya_ineuron.ipynb
# Programming_Assignment6_shreys_ineuron.ipynb
# Programming_Assignment7_shreya_ineuron.ipynb
# Programming_Assignment8_shreya_ineuron.ipynb
# Programming_Assignment9_shreya_ineuron.ipynb
# Programmming_Assignment19_shreya_ineuron.ipynb
# Python_Assessment_ineuron.ipynb
# Assignment_1_shreya_ineuron.ipynb
# README.md
# config
# description
# HEAD
# index
# packed-refs
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-merge-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# push-to-checkout.sample
# update.sample
# exclude
# HEAD
# main
# HEAD
# pack-06d50f880f406c6e7bbc62d5aa0f863d76444d4d.idx
# pack-06d50f880f406c6e7bbc62d5aa0f863d76444d4d.pack
# main
# HEAD
# Assignment_2_shreya_ineuron.ipynb
# README.md
# COMMIT_EDITMSG
# config
# description
# HEAD
# index
# packed-refs
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-merge-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# push-to-checkout.sample
# update.sample
# exclude
# HEAD
# main
# HEAD
# main
# 113c2dc84cd6388000424fc00adda05465f529
# dd94bc724ecf28f75e9b95627d01cd3c69294d
# adc96ddca5a189a829079e3785adb295eb58dc
# pack-c7a3dbe506bf019c5610bb93f2119cbc7c7c2744.idx
# pack-c7a3dbe506bf019c5610bb93f2119cbc7c7c2744.pack
# main
# HEAD
# main
# README.md
# Untitled.ipynb
# config
# description
# HEAD
# index
# packed-refs
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-merge-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# push-to-checkout.sample
# update.sample
# exclude
# HEAD
# main
# HEAD
# pack-9f1181d390fddc234d41499d8200056d4f3ba788.idx
# pack-9f1181d390fddc234d41499d8200056d4f3ba788.pack
# main
# HEAD
# Untitled-checkpoint.ipynb
# Essiesltd.pdf
# hundred.jpg
# pic.jpg
# data.xlsx
# Essiesltd.pdf
# numpy day 2-checkpoint.ipynb
# pandas and numpy-checkpoint.ipynb
# pandas class 3-checkpoint.ipynb
# pandas day 2-checkpoint.ipynb
# Pandas-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# EDA- Part 1.ipynb
# EDA- Part 1-checkpoint.ipynb
# 1-EDA And Feature Engineering.ipynb
# 2- BlackFriday EDA And Feature Engineering.ipynb
# LICENSE
# README.md
# Zomatodataset.zip
# Data_Train.xlsx
# FlightPrediction.ipynb
# Test_set.xlsx
# Feature Engineering.ipynb
# test.csv
# train.csv
# Feature Engineering-checkpoint.ipynb
# Data Science Interview Interview Questions(#Day28).pdf
# Data Science Interview Preparation Questions(#Day06).pdf
# Data Science Interview Preparation(# DAY 22).pdf
# Data Science Interview Preparation(#DAY 02).pdf
# Data Science Interview Preparation(#DAY 04).pdf
# Data Science Interview Preparation(#DAY 05).pdf
# Data Science Interview Preparation(#DAY 08).pdf
# Data Science Interview Preparation(#DAY 10).pdf
# Data Science Interview Preparation(#DAY 11).pdf
# Data Science Interview Preparation(#DAY 14).pdf
# Data Science Interview Preparation(#DAY 16).pdf
# Data Science Interview Preparation(#DAY 18).pdf
# Data Science Interview Preparation(#DAY 23).pdf
# Data Science Interview Preparation(#DAY 24).pdf
# Data Science Interview Preparation(#DAY 3).pdf
# Data Science Interview Preparation(#DAY 7).pdf
# Data Science Interview Preparation.pdf
# Data Science Interview Questiona(#Day21).pdf
# Data Science INterview Questions #Day1.pdf
# DATA SCIENCE INTERVIEW QUESTIONS(#DAY12).pdf
# DATA SCIENCE INTERVIEW QUESTIONS(#DAY13).pdf
# DATA SCIENCE INTERVIEW QUESTIONS(#DAY15).pdf
# Data Science Interview Questions(#Day17).pdf
# DATA SCIENCE INTERVIEW QUESTIONS(#DAY19).pdf
# Data Science Interview Questions(#DAY20).pdf
# Data science Interview Questions(#Day25).pdf
# Data Science Interview Questions(#Day26).pdf
# Data Science Interview Questions(#Day27).pdf
# DATA SCIENCE INTERVIEW QUESTIONS(#DAY9).pdf
# Final Data Science Interview Questions(#Day30).pdf
# 1-Simple Linearregression.pdf
# 2-RidgeLassoelasticLogistic.pdf
# 3-NaiveBayes&KNN.pdf
# 4- SSVM-SVR.pdf
# 5-Deicsion Tree Classifier And Regression.pdf
# 6-Randomforest.pdf
# 7-Adaboost.pdf
# 8-Gradientboosting-kmeanshierarichal.pdf
# airfoil_self_noise.dat
# Hands on Machine Learning with Scikit Learn and Tensorflow.pdf
# Hands_on_Machine_Learning_with_Scikit_Le.pdf
# Task_for_FSDS (1).pdf
# app.py
# LICENSE
# model.pkl
# Procfile
# README.md
# requirements.txt
# home.html
# Customers.csv
# hc.py
# README.md
# Customers.csv
# kmeanss.py
# README.md
# 01-K Nearest Neighbors with Python.ipynb
# Classified Data
# README.md
# Lassoand Regression.ipynb
# README.md
# README.md
# Untitled.ipynb
# README.md
# SVM Kernelss Implementation.ipynb
# 07 Functions_Revision (1).ipynb
# 07 Functions_Revision.ipynb
# 19.3 MongoDB (3).7z
# 19.3 MongoDB (4).7z
# deployment steps.pdf
# Exception handling class 1 (1).ipynb
# Exception handling class 2 (1).ipynb
# file sysetm.ipynb
# for loops while loop (1).ipynb
# Function and holiday task.ipynb
# Function continued.ipynb
# glass (1) (1).data
# Graph.ipynb
# graphs day 2.ipynb
# GUI Programming-1.ipynb
# GUI Programming-2.ipynb
# GUI Programming-3.ipynb
# GUI Programming-4.ipynb
# GUI Programming-5.ipynb
# GUI Programming-6.ipynb
# GUI Programming-7.ipynb
# if else , for loop.ipynb
# ImageScrapper.zip
# iterator generator.ipynb
# logging (1) (1).ipynb
# logging (1).ipynb
# mongodb class 1.ipynb
# Necessary Steps and Download link_.pdf
# numpy day 2.ipynb
# oops 29th  (1).ipynb
# oops 30th (1).ipynb
# oops class 1.ipynb
# pandas 4 .ipynb
# pandas and numpy.ipynb
# pandas class 3.ipynb
# pandas class homework discussed .ipynb
# pandas day 2.ipynb
# Pandas.ipynb
# practice problem python basic.ipynb
# Python basic (3).ipynb
# review scrapper.ipynb
# ReviewFlask.zip
# Session 1.1 - Python-Installation and Basics(1).ipynb
# sql day 2  (1).ipynb
# SQLLITE ,map ,reduce ,filter,zip.ipynb
# Tuples , set , dict  (1).ipynb
# Untitled.ipynb
# 07 Functions_Revision-checkpoint.ipynb
# Exception handling class 1 (1)-checkpoint.ipynb
# file sysetm-checkpoint.ipynb
# oops 30th (1)-checkpoint.ipynb
# stat3.pdf
# stats1.pdf
# stats2.pdf
# stats4.pdf
# stats5.pdf
# Hypothesis_Testing.ipynb
# README.md
# 09.Assignment-Radiation Amounts.xlsx
# Assignment8_Excel.xlsx
# Assignment_10excel.xlsx
# casandra.ipynb
# Convert-to-Date-Format (1).xlsx
# countif-sumif-exercises (1).xlsx
# example.txt
# Exception Handling.ipynb
# Find-Duplicates-and-Show-the-Count.xlsx
# Find-the-Position-of-Word (1).xlsx
# FUNCTIONS.ipynb
# Generate Multiplication Table (1).xlsx
# ineuron.db
# Iterator & Generator.ipynb
# Logging.ipynb
# Machine_Learning_Assignment1_shreya_ineuron.ipynb
# Many-Sums-Sample-Data.xlsx
# modules and packages.ipynb
# my_module.py
# my_module.py.txt
# OOPS.ipynb
# Palindrome (1).xlsx
# Radiation Amounts.xlsx
# SQL LITE.ipynb
# SQL.ipynb
# SQL_Assignment1_shreya_ineuron.ipynb
# SQL_Assignment2_shreya_ineuron.ipynb
# SQL_Assignment3_shreya_ieuron.ipynb
# SQL_Assignment4_shreya_ineuron.ipynb
# SQL_Assignment5_shreya_ineuron.ipynb
# SQL_Assignment6.ipynb
# SQL_Assignment7_shreya_ineuron.ipynb
# SQL_Assignment8_shreya_ineuron.ipynb
# SQL_Assignment9_shreya_ineuron.ipynb
# SS.txt
# Sum-for-Merged-Cells.xlsx
# task.ipynb
# test.log
# test.txt
# test1.py
# The Data Science Course 2021 - All Resources.zip
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Programmimg_Assignment5_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment3_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment7_shreya_ineuron-checkpoint.ipynb
# Programming_Assignment8_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment1_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment2_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment3_shreya_ieuron-checkpoint.ipynb
# SQL_Assignment4_shreya_ineuron-checkpoint.ipynb
# SQL_Assignment5_shreya_ineuron-checkpoint.ipynb
# description.nfo
# v32.cab
# v32_16.0.6769.2040.cab
# v64.cab
# v64_16.0.6769.2040.cab
# i320.cab
# i321033.cab
# i640.cab
# i641033.cab
# s320.cab
# s321033.cab
# s640.cab
# s641033.cab
# stream.x64.en-us.dat
# stream.x64.x-none.dat
# stream.x86.en-us.dat
# stream.x86.x-none.dat
# README.md
# shreya_flfpr_gdp.ipynb
# shreya_flfpr_gdp-checkpoint.ipynb
# my_module.cpython-39.pyc
# test1.cpython-39.pyc
# zoo.cpython-39.pyc

# %% [markdown]
# **5. Create a list of all of the files in your parent directory (minimum five files should be available).**

# %%
import os 
os.listdir()
# Out:
# ['$RECYCLE.BIN',
#  '.ipynb_checkpoints',
#  'application_log.txt',
#  'books.csv',
#  'books.db',
#  'ineuron',
#  'ineuron stuty material',
#  'Material',
#  'Microsoft Office Professional Plus 2016 + Activation Tool [danhuk]',
#  'new.jpg',
#  'Python_Assignment1_16.ipynb',
#  'Python_Assignment_10.ipynb',
#  'Python_Assignment_11.ipynb',
#  'Python_Assignment_12.ipynb',
#  'Python_Assignment_13.ipynb',
#  'Python_Assignment_14.ipynb',
#  'Python_Assignment_15.ipynb',
#  'Python_Assignment_17.ipynb',
#  'Python_Assignment_18.ipynb',
#  'Python_Assignment_19.ipynb',
#  'Python_Assignment_20.ipynb',
#  'Python_Assignment_21.ipynb',
#  'Python_Assignment_9.ipynb',
#  'Redis-x64-3.0.504.7z',
#  'Relation_between_FLFP_GDP-main',
#  'SQL.txt',
#  'System Volume Information',
#  'test.txt',
#  'today.txt',
#  'university_records.csv',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# **6. Create a date object of your day of birth.**

# %%
from datetime import datetime
my_dob = datetime.strptime('22/04/1997','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1997-04-22 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# **7. What day of the week was your day of birth?**

# %%
from datetime import datetime
my_dob = datetime(1997,4,22)
my_dob.strftime("%A")
# Out:
# 'Tuesday'

# %% [markdown]
# **8. When will you be (or when were you) 10,000 days old?**

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("22/04/1997",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1969, 12, 5, 0, 0)
